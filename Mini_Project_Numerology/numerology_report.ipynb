# %%
print("NUMEROLOGY REPORT")
name = input("Enter the name: ")
dob = input("Enter Birth Date in DD/MM/YYYY: ")


total_sum = 0

for char in dob:
    if char >= "0" and char <= "9":
        total_sum += int(char)


while True:
    if total_sum <= 9:
        break
    else:

        part1 = total_sum % 10
        part2 = total_sum // 10
        total_sum = part1 + part2


life_path_number = total_sum
print(f"Your Life Path Number is: {life_path_number}")

numerology_data = {
    1: [
        "The Leader (Sun)",
        "Leadership, independence, ambition, innovation, determination, courageous.",
        "Egoistic, arrogant, stubborn, self-centered, impatient, can suffer from isolation."
    ],
    2: [
        "The Peacemaker (Moon)",
        "Cooperation, diplomacy, sensitivity, intuitive, gentle, excellent partner/teammate, artistic.",
        "Overly sensitive, indecisive, shy, easily hurt by criticism, overly dependent on others."
    ],
    3: [
        "The Communicator (Jupiter)",
        "Creativity, self-expression, optimism, joy, charismatic, good communicator, social, inspiring.",
        "Scattered, superficial, prone to exaggeration or dramatization, lack of concentration, prone to worrying."
    ],
    4: [
        "The Builder (Rahu/Uranus)",
        "Stability, hard work, practicality, loyalty, discipline, reliable, dedicated to detail, consistent.",
        "Rigid, stubborn, restless, argumentative, inflexible, resistant to change, sometimes lazy or indecisive."
    ],
    5: [
        "The Free Soul (Mercury)",
        "Freedom, adventure, adaptability, versatile, high-spirited, magnetic, loves change and travel, great communicator.",
        "Impulsive, restless, quickly bored, tendency toward excess, irresponsible, non-committal."
    ],
    6: [
        "The Nurturer (Venus)",
        "Compassion, responsibility, love, harmony, artistic, nurturing, protective, family-oriented, dependable.",
        "Over-worrying, controlling, self-sacrificing (to their own detriment), perfectionistic, can be stubborn/meddling."
    ],
    7: [
        "The Seeker (Ketu/Neptune)",
        "Introspection, analysis, spirituality, deep thinker, intellectual, wise, truth-seeker, rational, intuitive.",
        "Reserved, overly skeptical, emotionally detached, argumentative, stubborn fixed opinions, secretive."
    ],
    8: [
        "The Powerhouse (Saturn)",
        "Success, abundance, authority, business savvy, confident, determined, amazing judgment, material power.",
        "Materialistic, manipulative, workaholic, greedy, domineering, prone to ego problems, sometimes narrow-minded."
    ],
    9: [
        "The Humanitarian (Mars)",
        "Compassion, selflessness, generosity, humanitarian, wisdom, completion, broad-minded, influential, artistic.",
        "Aloof, emotional intensity, prone to burnout, impulsive behavior, can be easily hurt by criticism, entitlement."
    ]
}

print("\n" + "="*20)
print("**USER PROFILE**")
print("Name:", name)
print(f"Date of Birth: {dob}")
print("="*20 + "\n")

print("**NUMEROLOGY ANALYSIS**")
data_list = numerology_data[life_path_number]
print(f"Life Path Number: {life_path_number} - {data_list[0]}")
print("\n**STRENGTHS**")
print(f"{data_list[1]}")
print("\n**CHALLENGES**")
print(f"{data_list[2]}")
print("\n**SUMMARY**")
print(f"Understanding your Life Path Number ({life_path_number}) helps you leverage your strengths for success. Focus on balancing your challenges for optimal career growth.")
print("\nBest regards,")
print("Atharva!")
